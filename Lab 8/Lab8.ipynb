# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataframe = pd.read_csv('Dataset/NetflixTVShowsandMovies.csv')

# %%
dataframe
# Out:
#       index         id                               title   type  \
# 0         0    tm84618                         Taxi Driver  MOVIE
# 1         1   tm127384     Monty Python and the Holy Grail  MOVIE
# 2         2    tm70993                       Life of Brian  MOVIE
# 3         3   tm190788                        The Exorcist  MOVIE
# 4         4    ts22164        Monty Python's Flying Circus   SHOW
# ...     ...        ...                                 ...    ...
# 5278   5278  tm1040816         Momshies! Your Soul is Mine  MOVIE
# 5279   5279  tm1014599                           Fine Wine  MOVIE
# 5280   5280  tm1045018                               Clash  MOVIE
# 5281   5281  tm1098060                      Shadow Parties  MOVIE
# 5282   5282   ts271048  Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     A mentally unstable Vietnam War veteran works ...          1976
# ...

# %%
dataframe['title'].value_counts()
# Out:
# title
# The Gift                              3
# Taxi Driver                           2
# Time Out                              2
# Love O2O                              2
# U Turn                                2
#                                      ..
# Safe                                  1
# The End of the F***ing World          1
# One Day at a Time                     1
# The Bureau of Magical Things          1
# Mighty Little Bheem: Kite Festival    1
# Name: count, Length: 5237, dtype: int64

# %%
dataframe.head(10)
# Out:
#    index        id                            title   type  \
# 0      0   tm84618                      Taxi Driver  MOVIE
# 1      1  tm127384  Monty Python and the Holy Grail  MOVIE
# 2      2   tm70993                    Life of Brian  MOVIE
# 3      3  tm190788                     The Exorcist  MOVIE
# 4      4   ts22164     Monty Python's Flying Circus   SHOW
# 5      5   tm14873                      Dirty Harry  MOVIE
# 6      6  tm185072                     My Fair Lady  MOVIE
# 7      7   tm98978                  The Blue Lagoon  MOVIE
# 8      8  tm119281                 Bonnie and Clyde  MOVIE
# 9      9   tm67378                The Professionals  MOVIE
#
#                                          description  release_year  \
# 0  A mentally unstable Vietnam War veteran works ...          1976
# 1  King Arthur, accompanied by his squire, recrui...          1975
# 2  Brian Cohen is an average young Jewish man, bu...          1979
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5283 entries, 0 to 5282
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              5283 non-null   int64
#  1   id                 5283 non-null   object
#  2   title              5283 non-null   object
#  3   type               5283 non-null   object
#  4   description        5278 non-null   object
#  5   release_year       5283 non-null   int64
#  6   age_certification  2998 non-null   object
#  7   runtime            5283 non-null   int64
#  8   imdb_id            5283 non-null   object
#  9   imdb_score         5283 non-null   float64
#  10  imdb_votes         5267 non-null   float64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 454.1+ KB

# %% [markdown]
# ##### plt.grid(True)
# plt.plot(dataframe['index'], dataframe['release_year'])
# # plt.title('WEIGHT / SOFTNESS')
# # plt.xlabel('Calories')
# plt.xticks(range(0, max(dataframe['release_year']) + 1, 500))
# # plt.ylabel('Softness')

# %%
plt.grid(True)
plt.plot(dataframe.head(125)['index'], dataframe.head(125)['release_year'])
plt.title('INDEX / RELEASE YEAR')
plt.xlabel('Index')
plt.ylabel('Release Year')
# plt.xticks(range(0, max(dataframe.head(125)['release_year']) + 1, 250))
# I didn't want to use xticks, Because it isn't eye catchy
# Out:
# Text(0, 0.5, 'Release Year')

# %%
plt.grid(True)
plt.scatter(dataframe.head(125)['runtime'], dataframe.head(125)['release_year'])
plt.title('Runtime and RELEASE YEAR')
plt.xlabel('Runtime')
plt.ylabel('Release Year')
# Out:
# Text(0, 0.5, 'Release Year')

# %%
type_color = {"MOVIE": "red",
               "SHOW": "yellow"
}
for type, type_color in type_color.items():
    type_dataframe = dataframe[dataframe['type'] == type]
    plt.scatter(type_dataframe.head(125)['index'], type_dataframe.head(125)['release_year'], c = type_color, label = type)

plt.grid(True)
plt.title('Runtime and RELEASE YEAR')
plt.xlabel('Runtime')
plt.ylabel('Release Year')
plt.legend()

# %%
sns.histplot(data = dataframe.head(125), x = 'release_year')
plt.title('Release year of every movie')
plt.xlabel('Year')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.histplot(data = dataframe.head(125), x = 'release_year')
plt.title('Release year of every movie')
plt.grid(axis = 'y')
plt.grid(axis = 'x')
plt.xlabel('Year')
plt.ylabel('Count')
plt.yticks(range(0,33, 3))
# Out:
# ([<matplotlib.axis.YTick at 0x248c2bf7680>,
# ...
#  [Text(0, 0, '0'),
#   Text(0, 3, '3'),
#   Text(0, 6, '6'),
#   Text(0, 9, '9'),
#   Text(0, 12, '12'),
#   Text(0, 15, '15'),
#   Text(0, 18, '18'),
#   Text(0, 21, '21'),
#   Text(0, 24, '24'),
#   Text(0, 27, '27'),
#   Text(0, 30, '30')])

# %%
sns.pairplot(dataframe.head(125), hue = 'release_year')
plt.show()

# %%
plt.figure(figsize = (8,6))
sns.boxplot(x = 'type', y = 'release_year', data = dataframe.head(125), palette = 'Set1')
plt.title('Box Plot')
plt.xlabel('type')
plt.ylabel('Release_Date')
# Out:
# C:\Users\amirp\AppData\Local\Temp\ipykernel_19652\2693816453.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'type', y = 'release_year', data = dataframe.head(125), palette = 'Set1')
# Text(0, 0.5, 'Release_Date')

# %%
plt.figure(figsize = (8,6))
sns.boxplot(x = 'type', y = 'release_year', data = dataframe.head(125), palette = 'Set1')
sns.swarmplot(x = 'type', y = 'release_year', data = dataframe.head(125), color = '.25')
plt.title('Swarm Plot')
plt.xlabel('type')
plt.ylabel('Release_Date')
# Out:
# C:\Users\amirp\AppData\Local\Temp\ipykernel_19652\813463330.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'type', y = 'release_year', data = dataframe.head(125), palette = 'Set1')
# Text(49.222222222222214, 0.5, 'Release_Date')

# %%
plt.figure(figsize = (8, 6))
sns.kdeplot(data = dataframe.head(125), x = 'release_year', hue = 'type', fill = True, common_norm = False, alpha = 0.4)
plt.title('KERNEL DENSITY PLOT')
plt.xlabel('release_year')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
sns.violinplot(x = 'type', y = 'release_year', data = dataframe.head(125))
plt.title('VIOLIN PLOT')
# Out:
# Text(0.5, 1.0, 'VIOLIN PLOT')
